# %% [markdown]
# What will be acomplish within day 4?
# - Sanity Check of New LP model
# - Sensitivity analysis of new LP (w/ Capacity)
# - Adding in weather adjusted demand to model (Modifing demand)
#
# <br>
# Interpretation:<br>
#
# For new LP the good capacity to maintain bikes in as shown in the heat map is have 120% of mean registered users per day on hand to maximize because after that there is very few mariginal gain opposed to cost used.<br>
#
# Weather adjusted demand:
# - Weathersit = 1 (1.0*demand)
# - Weathersit = 2 (0.85*demand)
# - Weathersit = 3 (0.65*demand)
# - Weathersit = 4 (0.4*demand)
# <br>
#
# For the new LP when you adjust the demand based on the weather you can see that the capacity needed changes based on the baseline LP you can see that all demand is fulfilled when the capacity of bikes is the same as the mean registered users for capacity, this is shown in the heatmap within the workbook.
