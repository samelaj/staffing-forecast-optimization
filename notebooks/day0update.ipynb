# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir(r"C:\Users\jakes\OneDrive\Documents\staffing-forecast-optimization")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jakes\\OneDrive\\Documents\\staffing-forecast-optimization'

# %%
df = pd.read_csv("hour.csv")
print(df)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df['hr'] = pd.to_datetime(df['hr'])

# %%
df = df.sort_values('hr')

# %%
plt.figure(figsize=(10,4))
plt.plot(df['hr'],df['cnt'])
plt.title("Count of Bikes Over Time (hrs)")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['hr'], df['registered'])
plt.title("Resgistered users Over Time (hrs)")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['hr'],df['casual'])
plt.title("Casual Users over Time (hrs)")
plt.show()
